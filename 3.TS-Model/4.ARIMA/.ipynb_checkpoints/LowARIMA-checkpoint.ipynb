# %%
import pandas as pd

# %%
from nsepy import get_history as gh
import datetime as dt

# %%
start = dt.datetime(2013,1,1)
end = dt.datetime(2021,12,28)
stk_data = gh(symbol='TATACOFFEE',start=start,end=end)
# Out:
# Exception in thread Thread-56:
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 720, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\util\retry.py", line 400, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\packages\six.py", line 734, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# urllib3.exceptions.ProtocolError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 138, in get_history
#     return get_history_quanta(**kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 146, in get_history_quanta
#     headers=headers, scaling=scaling)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 151, in url_to_df
#     resp = url(**params)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 167, in __call__
#     return self.session.get(url, params=kwargs, proxies = self.proxy )
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
#
# Exception in thread Thread-58:
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 720, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\util\retry.py", line 400, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\packages\six.py", line 734, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# urllib3.exceptions.ProtocolError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 138, in get_history
#     return get_history_quanta(**kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 146, in get_history_quanta
#     headers=headers, scaling=scaling)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 151, in url_to_df
#     resp = url(**params)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 167, in __call__
#     return self.session.get(url, params=kwargs, proxies = self.proxy )
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
#
# Exception in thread Thread-64:
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 720, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\util\retry.py", line 400, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\packages\six.py", line 734, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# urllib3.exceptions.ProtocolError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 138, in get_history
#     return get_history_quanta(**kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 146, in get_history_quanta
#     headers=headers, scaling=scaling)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 151, in url_to_df
#     resp = url(**params)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 167, in __call__
#     return self.session.get(url, params=kwargs, proxies = self.proxy )
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
#
# Exception in thread Thread-66:
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 720, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\util\retry.py", line 400, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\packages\six.py", line 734, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# urllib3.exceptions.ProtocolError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 138, in get_history
#     return get_history_quanta(**kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 146, in get_history_quanta
#     headers=headers, scaling=scaling)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 151, in url_to_df
#     resp = url(**params)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 167, in __call__
#     return self.session.get(url, params=kwargs, proxies = self.proxy )
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
#
# Exception in thread Thread-72:
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 720, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\util\retry.py", line 400, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\packages\six.py", line 734, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# urllib3.exceptions.ProtocolError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 138, in get_history
#     return get_history_quanta(**kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 146, in get_history_quanta
#     headers=headers, scaling=scaling)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 151, in url_to_df
#     resp = url(**params)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 167, in __call__
#     return self.session.get(url, params=kwargs, proxies = self.proxy )
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
#
# Exception in thread Thread-74:
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 720, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\util\retry.py", line 400, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\packages\six.py", line 734, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# urllib3.exceptions.ProtocolError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 138, in get_history
#     return get_history_quanta(**kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 146, in get_history_quanta
#     headers=headers, scaling=scaling)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 151, in url_to_df
#     resp = url(**params)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 167, in __call__
#     return self.session.get(url, params=kwargs, proxies = self.proxy )
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
# Exception in thread Thread-78:
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\contrib\pyopenssl.py", line 318, in recv_into
#     raise SocketError(str(e))
# OSError: (10060, 'WSAETIMEDOUT')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 720, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\util\retry.py", line 400, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\packages\six.py", line 734, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\contrib\pyopenssl.py", line 318, in recv_into
#     raise SocketError(str(e))
# urllib3.exceptions.ProtocolError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 138, in get_history
#     return get_history_quanta(**kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 146, in get_history_quanta
#     headers=headers, scaling=scaling)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 151, in url_to_df
#     resp = url(**params)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 167, in __call__
#     return self.session.get(url, params=kwargs, proxies = self.proxy )
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 668, in send
#     history = [resp for resp in gen] if allow_redirects else []
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 668, in <listcomp>
#     history = [resp for resp in gen] if allow_redirects else []
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 247, in resolve_redirects
#     **adapter_kwargs
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')"))
#
# Exception in thread Thread-82:
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\contrib\pyopenssl.py", line 318, in recv_into
#     raise SocketError(str(e))
# OSError: (10060, 'WSAETIMEDOUT')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 720, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\util\retry.py", line 400, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\packages\six.py", line 734, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\contrib\pyopenssl.py", line 318, in recv_into
#     raise SocketError(str(e))
# urllib3.exceptions.ProtocolError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 138, in get_history
#     return get_history_quanta(**kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 146, in get_history_quanta
#     headers=headers, scaling=scaling)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 151, in url_to_df
#     resp = url(**params)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 167, in __call__
#     return self.session.get(url, params=kwargs, proxies = self.proxy )
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 668, in send
#     history = [resp for resp in gen] if allow_redirects else []
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 668, in <listcomp>
#     history = [resp for resp in gen] if allow_redirects else []
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 247, in resolve_redirects
#     **adapter_kwargs
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')"))
#
# Exception in thread Thread-80:
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\contrib\pyopenssl.py", line 318, in recv_into
#     raise SocketError(str(e))
# OSError: (10060, 'WSAETIMEDOUT')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 720, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\util\retry.py", line 400, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\packages\six.py", line 734, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\contrib\pyopenssl.py", line 318, in recv_into
#     raise SocketError(str(e))
# urllib3.exceptions.ProtocolError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 138, in get_history
#     return get_history_quanta(**kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 146, in get_history_quanta
#     headers=headers, scaling=scaling)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 151, in url_to_df
#     resp = url(**params)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 167, in __call__
#     return self.session.get(url, params=kwargs, proxies = self.proxy )
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 668, in send
#     history = [resp for resp in gen] if allow_redirects else []
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 668, in <listcomp>
#     history = [resp for resp in gen] if allow_redirects else []
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 247, in resolve_redirects
#     **adapter_kwargs
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')"))
# Exception in thread Thread-86:
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
# ...
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')"))
#
# Exception in thread Thread-93:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
#
# Exception in thread Thread-92:
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\contrib\pyopenssl.py", line 318, in recv_into
#     raise SocketError(str(e))
# OSError: (10060, 'WSAETIMEDOUT')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 720, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\util\retry.py", line 400, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\packages\six.py", line 734, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py", line 416, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\envs\ML\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\envs\ML\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\urllib3\contrib\pyopenssl.py", line 318, in recv_into
#     raise SocketError(str(e))
# urllib3.exceptions.ProtocolError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 138, in get_history
#     return get_history_quanta(**kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 146, in get_history_quanta
#     headers=headers, scaling=scaling)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 151, in url_to_df
#     resp = url(**params)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 167, in __call__
#     return self.session.get(url, params=kwargs, proxies = self.proxy )
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 668, in send
#     history = [resp for resp in gen] if allow_redirects else []
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 668, in <listcomp>
#     history = [resp for resp in gen] if allow_redirects else []
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 247, in resolve_redirects
#     **adapter_kwargs
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Ramisha Krishnasamy\AppData\Roaming\Python\Python37\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')"))
#
# Exception in thread Thread-91:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
#
# Exception in thread Thread-89:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
#
# Exception in thread Thread-87:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
#
# Exception in thread Thread-85:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
#
# Exception in thread Thread-83:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
#
# Exception in thread Thread-81:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
#
# Exception in thread Thread-79:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
#
# Exception in thread Thread-77:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
#
# Exception in thread Thread-75:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
#
# Exception in thread Thread-73:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
#
# Exception in thread Thread-71:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
#
# Exception in thread Thread-69:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
#
# Exception in thread Thread-67:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
# Exception in thread Thread-65:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
#
# Exception in thread Thread-63:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
#
# Exception in thread Thread-61:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
#
# Exception in thread Thread-59:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
#
# Exception in thread Thread-57:
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\ML\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py", line 136, in get_history
#     return pd.concat((t1.result, t2.result))
# AttributeError: 'ThreadReturns' object has no attribute 'result'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-dcb64786f380> in <module>
#       1 start = dt.datetime(2013,1,1)
#       2 end = dt.datetime(2021,12,28)
# ----> 3 stk_data = gh(symbol='TATACOFFEE',start=start,end=end)
#
# C:\Anaconda3\envs\ML\lib\site-packages\nsepy\history.py in get_history(symbol, start, end, index, futures, option_type, expiry_date, strike_price, series)
#     134         t1.join()
#     135         t2.join()
# --> 136         return pd.concat((t1.result, t2.result))
#     137     else:
#     138         return get_history_quanta(**kwargs)
#
# AttributeError: 'ThreadReturns' object has no attribute 'result'

# %%
stk_data=stk_data[["Open","High","Low","Close"]]
stk_data.to_csv("Tatacoffee13_21.csv")

# %%
column="Low"

# %%
from sklearn.preprocessing import MinMaxScaler
Ms = MinMaxScaler()
data1= Ms.fit_transform(stk_data[[column]])
print("Len:",data1.shape)

# %%
training_size = round(len(data1 ) * 0.80)
print(training_size)
X_train=data1[:training_size]
X_test=data1[training_size:]
print("X_train length:",X_train.shape)
print("X_test length:",X_test.shape)
y_train=data1[:training_size]
y_test=data1[training_size:]
print("y_train length:",y_train.shape)
print("y_test length:",y_test.shape)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#len(y_pred)

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(X_train, order=(1,0,0))
model_fit = model.fit()
# make prediction
y_pred= model_fit.predict(len(X_train), len(data1)-1)
from stockFunctions import rmsemape
rmsemape(y_test,y_pred)
print("************")

# %%
from stockFunctions import graph
graph(y_test,y_pred,"Actual","Predicted","TataCoffee-Low-ARIMA-Norm","Days","Prices")

# %%
len(data1)

# %%
from stockFunctions import conversionSingle
aTestNormTable=conversionSingle(y_test,[column])
actual_stock_price_test_ori=Ms.inverse_transform(aTestNormTable)
actual_stock_price_test_oriA=conversionSingle(actual_stock_price_test_ori,[column])

# %%
from stockFunctions import conversionSingle
pTestNormTable=conversionSingle(y_pred,[column])
predicted_stock_price_test_ori=Ms.inverse_transform(pTestNormTable)
predicted_stock_price_test_oriP=conversionSingle(predicted_stock_price_test_ori,[column])

# %%
predicted_stock_price_test_oriP.to_csv("pLowArima.csv",index=False)

# %%
from stockFunctions import graph
graph(actual_stock_price_test_oriA,predicted_stock_price_test_oriP,"Actual","Predicted","TataCoffee-Low-ARIMA-Ori","Days","Prices")

# %%
from stockFunctions import rmsemape
rmsemape(actual_stock_price_test_oriA,predicted_stock_price_test_oriP)
# Out:
# RMSE-Testset: 69.38331032724119
# maPe-Testset: 0.4922968214852462

# %%
forecast=model_fit.predict(len(data1), len(data1)+30)

# %%
forecast
# Out:
# array([0.1530229 , 0.15319061, 0.15335785, 0.15352461, 0.15369092,
#        0.15385675, 0.15402212, 0.15418702, 0.15435146, 0.15451544,
#        0.15467896, 0.15484202, 0.15500463, 0.15516677, 0.15532846,
#        0.1554897 , 0.15565048, 0.15581081, 0.1559707 , 0.15613013,
#        0.15628911, 0.15644765, 0.15660575, 0.1567634 , 0.15692061,
#        0.15707737, 0.1572337 , 0.15738958, 0.15754503, 0.15770005,
#        0.15785462])

# %%
from stockFunctions import conversionSingle
fTestNormTable=conversionSingle(forecast,["Lowfore"])
forecast_stock_price_test_ori=Ms.inverse_transform(fTestNormTable)
forecast_stock_price_test_oriF=conversionSingle(forecast_stock_price_test_ori,["Lowfore"])

# %%
forecast_stock_price_test_oriF
# Out:
#     Lowfore
# 0   291.146
# 1   291.412
# 2   291.678
# 3   291.943
# 4   292.207
# 5   292.471
# 6   292.733
# 7   292.995
# 8   293.257
# 9   293.517
# 10  293.777
# 11  294.036
# 12  294.295
# 13  294.552
# 14  294.809
# 15  295.065
# 16  295.321
# 17  295.576
# 18   295.83
# 19  296.083
# 20  296.336
# 21  296.587
# 22  296.839
# 23  297.089
# 24  297.339
# 25  297.588
# 26  297.836
# 27  298.084
# 28  298.331
# 29  298.577
# 30  298.823

# %%
forecast_stock_price_test_oriF.to_csv("LowARIMA.csv",index=False)
