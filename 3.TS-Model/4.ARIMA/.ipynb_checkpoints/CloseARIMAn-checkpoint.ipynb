# %%
import pandas as pd

# %%
from nsepy import get_history as gh
import datetime as dt

# %%
start = dt.datetime(2013,1,1)
end = dt.datetime(2021,12,28)
stk_data = gh(symbol='TATACOFFEE',start=start,end=end)

# %%
stk_data=stk_data[["Open","High","Low","Close"]]
stk_data.to_csv("Tatacoffee13_21.csv")

# %%
column="Close"

# %%
from sklearn.preprocessing import MinMaxScaler
Ms = MinMaxScaler()
data1= Ms.fit_transform(stk_data[[column]])
print("Len:",data1.shape)
# Out:
# Len: (2225, 1)

# %%
training_size = round(len(data1 ) * 0.80)
print(training_size)
X_train=data1[:training_size]
X_test=data1[training_size:]
print("X_train length:",X_train.shape)
print("X_test length:",X_test.shape)
y_train=data1[:training_size]
y_test=data1[training_size:]
print("y_train length:",y_train.shape)
print("y_test length:",y_test.shape)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#len(y_pred)

# %%
i=1
td="t"
model = ARIMA(X_train, order=(1,0,0))
model_fit = model.fit()
# make prediction
y_pred= model_fit.predict(len(X_train), len(data1)-1)
#print(y_pred)
from sklearn.metrics import r2_score
mse=mean_squared_error(y_test,y_pred,squared=False)
from stockFunctions import rmsemape
rmsemape(y_test,y_pred)
print("************")

# %%
from stockFunctions import graph
graph(y_test,y_pred,"Actual","Predicted","TataCoffee-Close-ARIMA-Norm","Days","Prices")

# %%
len(data1)
# Out:
# 2225

# %%
from stockFunctions import conversionSingle
aTestNormTable=conversionSingle(y_test,[column])
actual_stock_price_test_ori=Ms.inverse_transform(aTestNormTable)
actual_stock_price_test_oriA=conversionSingle(actual_stock_price_test_ori,[column])

# %%
actual_stock_price_test_oriA
# Out:
#       Close
# 0      64.3
# 1      63.1
# 2      60.7
# 3      58.7
# 4      59.8
# ..      ...
# 440     205
# 441  202.95
# 442     201
# 443  218.35
# 444  212.35
#
# [445 rows x 1 columns]

# %%
from stockFunctions import conversionSingle
pTestNormTable=conversionSingle(y_pred,[column])
predicted_stock_price_test_ori=Ms.inverse_transform(pTestNormTable)
predicted_stock_price_test_oriP=conversionSingle(predicted_stock_price_test_ori,[column])

# %%
predicted_stock_price_test_oriP.to_csv("pCloseArima.csv",index=False)

# %%
len(predicted_stock_price_test_oriP)
# Out:
# 445

# %%
from stockFunctions import graph
graph(actual_stock_price_test_oriA,predicted_stock_price_test_oriP,"Actual","Predicted","TataCoffee-Close-ARIMA-Ori","Days","Prices")

# %%
from stockFunctions import rmsemape
rmsemape(actual_stock_price_test_oriA,predicted_stock_price_test_oriP)
# Out:
# RMSE-Testset: 70.548461516032
# maPe-Testset: 0.5174532337759596

# %%
forecast=model_fit.predict(len(data1), len(data1)+30)

# %%
forecast
# Out:
# array([0.15187665, 0.15204081, 0.15220452, 0.1523678 , 0.15253064,
#        0.15269305, 0.15285503, 0.15301657, 0.15317768, 0.15333837,
#        0.15349862, 0.15365845, 0.15381785, 0.15397682, 0.15413538,
#        0.1542935 , 0.15445121, 0.1546085 , 0.15476536, 0.15492181,
#        0.15507784, 0.15523346, 0.15538866, 0.15554344, 0.15569782,
#        0.15585178, 0.15600533, 0.15615847, 0.1563112 , 0.15646353,
#        0.15661545])

# %%
from stockFunctions import conversionSingle
fTestNormTable=conversionSingle(forecast,["Closefore"])
forecast_stock_price_test_ori=Ms.inverse_transform(fTestNormTable)
forecast_stock_price_test_oriF=conversionSingle(forecast_stock_price_test_ori,["Closefore"])

# %%
forecast_stock_price_test_oriF
# Out:
#    Closefore
# 0     292.22
# 1    292.483
# 2    292.745
# 3    293.006
# 4    293.266
# 5    293.526
# 6    293.785
# 7    294.043
# 8      294.3
# 9    294.557
# 10   294.814
# 11   295.069
# 12   295.324
# 13   295.578
# 14   295.832
# 15   296.084
# 16   296.337
# 17   296.588
# 18   296.839
# 19   297.089
# 20   297.338
# 21   297.587
# 22   297.835
# 23   298.083
# 24    298.33
# 25   298.576
# 26   298.821
# 27   299.066
# 28    299.31
# 29   299.554
# 30   299.797

# %%
forecast_stock_price_test_oriF.to_csv("CloseARIMA.csv",index=False)

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(data1, order=(1,0,0))
model_fit = model.fit()
# make prediction
forecast_seq=model_fit.predict(len(data1), len(data1)+120)
from stockFunctions import conversionSingle
fTestNormTable=conversionSingle(forecast_seq,["Close"])
forecast_stock_price_test_ori=Ms.inverse_transform(fTestNormTable)
forecast_stock_price_test_oriFS=conversionSingle(forecast_stock_price_test_ori,["Close"])
forecast_stock_price_test_oriFS.to_csv("CloseArima_120F.csv",index=False)
